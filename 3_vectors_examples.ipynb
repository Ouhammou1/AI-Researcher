# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
v1 = np.array([3,4])
v2 = np.array([-2,1])
v3 = np.array([1,5])


fig ,ax= plt.subplots(figsize=(7,5))
ax.quiver(0, 0 ,v1[0] , v1[1] , angles='xy' , scale_units='xy' , scale=1 , color='r' , width=0.005  , label='v1 = {v1}')
ax.quiver(0, 0 ,v2[0] , v2[1] , angles='xy' , scale_units='xy' , scale=1 , color='b' , width=0.005  , label='v1 = {v1}')
ax.quiver(0, 0 ,v3[0] , v3[1] , angles='xy' , scale_units='xy' , scale=1 , color='g' , width=0.005  , label='v1 = {v1}')


ax.set_xlim(-5, 5)
ax.set_ylim(-1, 6)
# ax.set_xlabel('x')
# ax.set_ylabel('y')
# ax.set_title('Vectors as Arrows')
# ax.grid(True)
# ax.legend()
# ax.set_aspect('equal')
# plt.axhline(y=0, color='k', linewidth=0.5)
# plt.axvline(x=0, color='k', linewidth=0.5)

plt.grid()
plt.show()

# %%
v1 = np.array([3,4])
v2 = np.array([-2,1])
v3 = np.array([1,5])


fig ,ax= plt.subplots(figsize=(7,5))
ax.quiver(0, 0 ,v1[0] , v1[1] , angles='xy' , scale_units='xy' , scale=1 , color='r' , width=0.005  , label='v1 = {v1}')
ax.quiver(v1[0] , v1[1]  ,v2[0] , v2[1] , angles='xy' , scale_units='xy' , scale=1 , color='b' , width=0.005  , label='v1 = {v1}')
ax.quiver(0, 0 ,v3[0] , v3[1] , angles='xy' , scale_units='xy' , scale=1 , color='g' , width=0.005  , label='v1 = {v1}')


ax.set_xlim(-5, 5)
ax.set_ylim(-1, 6)
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_title('Vectors as Arrows')
ax.grid(True)
ax.legend()
ax.set_aspect('equal')
plt.axhline(y=0, color='k', linewidth=0.5)
plt.axvline(x=0, color='k', linewidth=0.5)

plt.grid()
plt.show()

# %%
v1 = np.array([2,4])
v2 = np.array([4,8])
v3 = np.array([8,16])


fig ,ax= plt.subplots(figsize=(7,5))
ax.quiver(0, 0 ,v1[0] , v1[1] , angles='xy' , scale_units='xy' , scale=1 , color='r' , width=0.005  , label='v1 = {v1}')
ax.quiver(v1[0] , v1[1]  ,v2[0] , v2[1] , angles='xy' , scale_units='xy' , scale=1 , color='b' , width=0.005  , label='v1 = {v1}')
ax.quiver(v2[0] , v2[1] ,v3[0] , v3[1] , angles='xy' , scale_units='xy' , scale=1 , color='g' , width=0.005  , label='v1 = {v1}')


ax.set_xlim(0, 20)
ax.set_ylim(0, 20)
plt.grid()
plt.show()

# %%
v1 = np.array([2,4])
v2 = np.array([4,8])
v3 = np.array([8,16])


fig ,ax= plt.subplots(figsize=(7,5))
ax.quiver(v1[0] , v1[1] ,0, 0  , angles='yx' , scale_units='xy' , scale=1 , color='r' , width=0.005  , label='v1 = {v1}')
ax.quiver(v1[0] , v1[1]  ,v2[0] , v2[1] , angles='xy' , scale_units='xy' , scale=1 , color='b' , width=0.005  , label='v1 = {v1}')
ax.quiver(v2[0] , v2[1] ,v3[0] , v3[1] , angles='xy' , scale_units='xy' , scale=1 , color='g' , width=0.005  , label='v1 = {v1}')


ax.set_xlim(0, 20)
ax.set_ylim(0, 20)
plt.grid()
plt.show()

# %%
import numpy as np

a = np.array([2, 3])
b = np.array([4, 1])

dot = np.dot(a, b)
print(dot)  # Output: 11
# Out:
# 11

# %%
v1  = np.array([3,4])
v2  = np.array([1,2])
v3  = np.array([-4,3])
v4  = np.array([-3,-4])


# dot1 = np.dot(v1,v2)
# print(dot1)

# dot2 = np.dot(v2,v3)
# print(dot2)

# dot3 = np.dot(v3,v4)
# print(dot3)

print(f"v1 = {v1}")
print(f"v2 = {v2}")
print(f"v1 · v2 = {v1[0]}*{v2[0]} + {v1[1]}*{v2[1]} = {v1[0]*v2[0]} + {v1[1]*v2[1]} = {dot1}")
print()

print(f"v1 = {v1}")
print(f"v3 = {v3}")
print(f"v1 · v3 = {v1[0]}*{v3[0]} + {v1[1]}*{v3[1]} = {v1[0]*v3[0]} + {v1[1]*v3[1]} = {dot2} (perpendicular!)")
print()

print(f"v1 = {v1}")
print(f"v4 = {v4}")
print(f"v1 · v4 = {v1[0]}*{v4[0]} + {v1[1]}*{v4[1]} = {v1[0]*v4[0]} + {v1[1]*v4[1]} = {dot3} (opposite!)")
# Out:
# v1 = [3 4]
# v2 = [1 2]
# v1 · v2 = 3*1 + 4*2 = 3 + 8 = 11
#
# v1 = [3 4]
# v3 = [-4  3]
# v1 · v3 = 3*-4 + 4*3 = -12 + 12 = 2 (perpendicular!)
#
# v1 = [3 4]
# v4 = [-3 -4]
# v1 · v4 = 3*-3 + 4*-4 = -9 + -16 = 0 (opposite!)

# %%
fig , ax  = plt.subplots(figsize=(12,10))

x = np.linspace(0,10,100)
y = x *2

for i in range(5):
    ax.plot(x+10,y-10)
    x= x+10
    y =y-10

# %%
fig , ax  = plt.subplots(figsize=(12,10))


vectors = [
    (v1, 'b', 'v1'),
    (v2, 'r', f'v2 (dot = {dot1:.1f})'),
    (v3, 'g', f'v3 (dot = {dot2:.1f}, perpendicular)'),
    (v4, 'orange', f'v4 (dot = {dot3:.1f}, opposite)'),
]


for vec , color , label in vectors:
    ax.quiver(0,0, vec[0], vec[1] , angles='xy' , scale_units='xy' , scale=1 , color=color,
             width=0.01 , label=label)

ax.set_xlim(-5, 5)
ax.set_ylim(-5, 5)
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_title('Dot Product Examples')
ax.grid(True)
ax.legend()
ax.set_aspect('equal')
plt.axhline(y=0, color='k', linewidth=0.5)
plt.axvline(x=0, color='k', linewidth=0.5)
plt.show()

# %%
fig , ax  = plt.subplots(figsize=(12,10))


vectors = [
    (v1, 'b', 'v1'),
    (v2, 'r', f'v2 (dot = {dot1:.1f})'),
    (v3, 'g', f'v3 (dot = {dot2:.1f}, perpendicular)'),
    (v4, 'orange', f'v4 (dot = {dot3:.1f}, opposite)'),
]


for vec , color , label in vectors:
    ax.quiver(0,0, vec[0], vec[1] , angles='xy' , scale_units='xy' , scale=1 , color=color,
             width=0.01 , label=label)

ax.set_xlim(-5, 5)
ax.set_ylim(-5, 5)
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_title('Dot Product Examples')
ax.grid(True)
ax.legend()
ax.set_aspect('equal')
plt.axhline(y=0, color='k', linewidth=0.5)
plt.axvline(x=0, color='k', linewidth=0.5)
plt.show()
