# %%
import  torch as t

# %%
T = t.tensor([ [1,2,3, 10],
            [4,5 ,6,11],
             [7,8, 9,12]])

print(f"t[0] = {T[0]}")
# Out:
# t[0] = tensor([ 1,  2,  3, 10])

# %%
print(f" T[: , 0] {T[:,0]}")
# Out:
#  T[: , 0] tensor([1, 4, 7])

# %%
print(f" T[: , 0] {T[:,1]}")
# Out:
#  T[: , 0] tensor([2, 5, 8])

# %%
print(f" T[: , 0] = {T[0,2]}")
# Out:
#  T[: , 0]  3

# %%
print(f" T[: , 0] = {T[:,0:1]}")
# Out:
#  T[: , 0] = tensor([[1],
#         [4],
#         [7]])

# %%
print(f" T[: , 0] = {T[T>5]}")
# Out:
#  T[: , 0] = tensor([10,  6, 11,  7,  8,  9, 12])

# %% [markdown]
# CONCATENATE

# %%
t1 =  t.tensor([[1 , 2 ,8],
                  [3, 4 ,3]])

t2 =  t.tensor([[5 , 6 ],
                  [7, 8]])

# %%
t_cat0 = torch.cat([t1 ,t2]  , dim=1)
print(t_cat0 )
# Out:
# tensor([[1, 2, 8, 5, 6],
#         [3, 4, 3, 7, 8]])
